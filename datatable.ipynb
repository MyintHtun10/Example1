# %% [markdown]
# <a href="https://colab.research.google.com/github/MyintHtun10/Example1/blob/main/datatable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Name": ["Aung Aung", "Su Su", "Mg Mg", "Mya Mya", "Hla Hla"],
    "Math": [80, 90, 65, 75, 88],
    "English": [75, 85, 70, 80, 90],
    "Science": [90, 88, 60, 78, 85]
}

df = pd.DataFrame(data)
df

df["Average"] = df[["Math", "English", "Science"]].mean(axis=1)

df
# Out:
#         Name  Math  English  Science    Average
# 0  Aung Aung    80       75       90  81.666667
# 1      Su Su    90       85       88  87.666667
# 2      Mg Mg    65       70       60  65.000000
# 3    Mya Mya    75       80       78  77.666667
# 4    Hla Hla    88       90       85  87.666667
