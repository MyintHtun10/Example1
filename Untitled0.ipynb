# %% [markdown]
# <a href="https://colab.research.google.com/github/MyintHtun10/Example1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Wirld")
# Out:
# Hello Wirld

# %%
name=input("Enter your name")
print(" welcome ", name)
# Out:
# Enter your nameMyint Theeda
#  welcome  Myint Theeda

# %%
number1=int(input("Enter first number"))
number2=int(input("Enter second number"))
print(number1*number2)
