# %% [markdown]
# <a href="https://colab.research.google.com/github/MyintHtun10/Example1/blob/main/EEE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age=int(input("enter your age"))
while age<0 or age>100:
  print("pls re enter")
if age<11:
  print("You are Child")
elif age<20:
  print("You are Adult")
else:
  print("You are Old")
# Out:
# enter your age45
# You are Old
