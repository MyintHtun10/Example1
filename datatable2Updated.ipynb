# %% [markdown]
# <a href="https://colab.research.google.com/github/MyintHtun10/Example1/blob/main/datatable2Updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Name": ["Aung Aung", "Su Su", "Mg Mg", "Mya Mya", "Hla Hla"],
    "Math": [80, 90, 65, 75, 88],
    "English": [75, 85, 70, 80, 90],
    "Science": [90, 88, 60, 78, 85]
}

df = pd.DataFrame(data)
df

df["Average"] = df[["Math", "English", "Science"]].mean(axis=1)

df

df["Result"] = df["Average"].apply(
    lambda x: "Pass" if x >= 50 else "Fail"
)

df

import matplotlib.pyplot as plt

plt.bar(df["Name"], df["Average"])

plt.title("Student Average Performance")
plt.xlabel("Students")
plt.ylabel("Average Mark")

plt.show()
