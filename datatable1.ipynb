# %% [markdown]
# <a href="https://colab.research.google.com/github/MyintHtun10/Example1/blob/main/datatable1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Item": ["Apple", "Banana", "Coconut", "Durian", "Papaya"],
    "Quantity": [7, 2, 5, 1, 8],
    "Price": [7500, 5000, 3000, 80000, 4000]
}

df = pd.DataFrame(data)

df["Amount"] = df["Quantity"] * df["Price"]

df


### 📊 Result
# Out:
#       Item  Quantity  Price  Amount
# 0    Apple         7   7500   52500
# 1   Banana         2   5000   10000
# 2  Coconut         5   3000   15000
# 3   Durian         1  80000   80000
# 4   Papaya         8   4000   32000
